# %% [markdown]
# # 🧠 Vibe Matcher — Mini Fashion Recommender
# This Colab-ready notebook matches vibe queries (e.g., 'energetic urban chic') to fashion items using OpenAI embeddings.

# %%
# !pip install openai scikit-learn matplotlib pandas --quiet
import time, numpy as np, pandas as pd, matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from openai import OpenAI
client = OpenAI(api_key='YOUR_OPENAI_API_KEY')
